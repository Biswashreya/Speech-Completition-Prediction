# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import spacy

df = pd.read_csv("../clustering/intermediate_data/clustered_embeddings.csv")
df = df[df["text"].notnull() & df["cluster"].notnull()]

grouped = df.groupby("cluster")["text"].apply(lambda x: " ".join(x)).reset_index()
grouped.columns = ["cluster", "combined_text"]

nlp = spacy.load("en_core_web_sm")

def textrank_keywords(text, top_n=5):
    doc = nlp(text)
    candidates = [chunk.text for chunk in doc.noun_chunks]
    vectorizer = TfidfVectorizer(stop_words='english')
    X = vectorizer.fit_transform(candidates)
    scores = X.sum(axis=0).A1
    keywords = [vectorizer.get_feature_names_out()[i] for i in scores.argsort()[::-1][:top_n]]
    return keywords

for i, row in grouped.iterrows():
    print(f"\nCluster {row['cluster']}")
    print("TextRank:", textrank_keywords(row["combined_text"]))
# Out:
# Cluster -1
# TextRank: ['graph', 'edge', 'vertex', 'vertices', 'edges']
#
# Cluster 0
# TextRank: ['person', 'hands', 'people', 'handshakes', 'number']
#
# Cluster 1
# TextRank: ['lecture', 'modules', 'class', 'theory', 'thank']
#
# Cluster 2
# TextRank: ['banks', 'island', 'bridge', 'islands', 'bank']
#
# Cluster 3
# TextRank: ['size', 'neighbors', 'set', 'subset', 'union']
#
# Cluster 4
# TextRank: ['lecture', 'graphs', 'notion', 'graph', 'music']
#
# Cluster 5
# TextRank: ['lecture', 'mathematics', 'theory', 'mooc', 'number']
#
# Cluster 6
# TextRank: ['number', 'edge', 'whites', 'level', 'divisor']
#
# Cluster 7
# TextRank: ['node', 'leaf', 'neighbor', 'nodes', 'tree']
#
# Cluster 8
# TextRank: ['matching', 'perfect', 'condition', 'size', 'set']
#
# Cluster 9
# TextRank: ['matching', 'maximum', 'vertex', 'edges', 'sense']
#
# Cluster 10
# TextRank: ['vertices', 'graph', 'matching', 'size', 'number']
#
# Cluster 11
# TextRank: ['graph', 'people', 'edge', 'person', 'vertices']
#
# Cluster 12
# TextRank: ['distance', 'interval', 'point', 'right', 'left']
#
# Cluster 13
# TextRank: ['fraction', 'prime', 'new', 'position', 'differs']
#
# Cluster 14
# TextRank: ['fraction', 'enumeration', 'new', 'position', 'second']
#
# Cluster 15
# TextRank: ['bfs', 'vertex', 'graph', 'search', 'breadthfirst']
#
# Cluster 16
# TextRank: ['dfs', 'neighbor', 'ordering', 'sequence', 'restrictions']
#
# Cluster 17
# TextRank: ['dfs', 'vertex', 'color', 'stack', 'recursive']
#
# Cluster 18
# TextRank: ['qa', 'point', 'line', 'real', 'integers']
#
# Cluster 19
# TextRank: ['algorithm', 'division', 'gcd', 'theorem', 'naught']
#
# Cluster 20
# TextRank: ['vertices', 'order', 'stack', 'ordering', 'vertex']
#
# Cluster 21
# TextRank: ['graph', 'planar', 'particular', 'edges', 'edge']
#
# Cluster 22
# TextRank: ['queue', 'vertex', 'vertices', 'element', 'algorithm']
#
# Cluster 23
# TextRank: ['level', 'vertices', 'neighbors', 'vertex', 'neighbor']
#
# Cluster 24
# TextRank: ['ancestor', 'common', 'path', 'level', 'paths']
#
# Cluster 25
# TextRank: ['real', 'line', 'interval', 'set', 'origin']
#
# Cluster 26
# TextRank: ['paths', 'crossing', 'drawing', 'crossings', 'case']
#
# Cluster 27
# TextRank: ['power', 'positive', 'numbers', 'property', 'product']
#
# Cluster 28
# TextRank: ['set', 'hypothesis', 'theory', 'continuum', 'discussion']
#
# Cluster 29
# TextRank: ['minus', 'elements', 'lists', 'size', 'list']
#
# Cluster 30
# TextRank: ['minus', 'integer', 'integers', 'negative', 'sum']
#
# Cluster 31
# TextRank: ['numbers', 'number', 'lcm', 'exponent', 'product']
#
# Cluster 32
# TextRank: ['point', 'place', 'way', 'course', 'goes']
#
# Cluster 33
# TextRank: ['graph', 'bipartite', 'vertices', 'edges', 'graphs']
#
# Cluster 34
# TextRank: ['graph', 'cycles', 'odd', 'cycle', 'lengths']
#
# Cluster 35
# TextRank: ['factorial', 'number', 'sequence', 'sum', 'divides']
#
# Cluster 36
# TextRank: ['prime', 'delta', 'graph', 'colors', 'smaller']
#
# Cluster 37
# TextRank: ['neighbors', 'neighbor', 'course', 'amp', 'block']
#
# Cluster 38
# TextRank: ['product', 'eye', 'congruence', 'ri', 'congruent']
#
# Cluster 39
# TextRank: ['flow', 'capacity', 'edges', 'edge', 'value']
#
# Cluster 40
# TextRank: ['congruent', 'minus', 'integers', 'mod', 'second']
#
# Cluster 41
# TextRank: ['prime', 'pair', 'ordered', 'halls', 'ape']
#
# Cluster 42
# TextRank: ['number', 'square', 'sides', 'equation', 'root']
#
# Cluster 43
# TextRank: ['ri', 'mod', 'gcd', 'congruent', 'lecture']
#
# Cluster 44
# TextRank: ['theorem', 'product', 'integers', 'prime', 'integer']
#
# Cluster 45
# TextRank: ['residue', 'phi', 'modulo', 'complete', 'integer']
#
# Cluster 46
# TextRank: ['prime', 'factorization', 'product', 'power', 'canonical']
#
# Cluster 47
# TextRank: ['combination', 'linear', 'coefficients', 'integers', 'member']
#
# Cluster 48
# TextRank: ['set', 'members', 'elements', 'count', 'correspondence']
#
# Cluster 49
# TextRank: ['neighbors', 'nodes', 'node', 'neighbor', 'seven']
#
# Cluster 50
# TextRank: ['red', 'edge', 'vertex', 'edges', 'blue']
#
# Cluster 51
# TextRank: ['congruent', 'modulo', 'ax', 'integers', 'mi']
#
# Cluster 52
# TextRank: ['congruent', 'modem', 'minus', 'ac', 'remainder']
#
# Cluster 53
# TextRank: ['set', 'rational', 'number', 'numbers', 'cut']
#
# Cluster 54
# TextRank: ['algorithm', 'coloring', 'greedy', 'color', 'graph']
#
# Cluster 55
# TextRank: ['integers', 'minus', 'set', 'negative', 'product']
#
# Cluster 56
# TextRank: ['root', 'bc', 'integer', 'ad', 'addition']
#
# Cluster 57
# TextRank: ['norm', 'members', 'product', 'minus', 'value']
#
# Cluster 58
# TextRank: ['lambda', 'cardinality', 'kappa', 'elements', 'set']
#
# Cluster 59
# TextRank: ['vertex', 'colors', 'vortex', 'neighbors', 'neighbor']
#
# Cluster 60
# TextRank: ['vertex', 'color', 'dot', 'start', 'phase']
#
# Cluster 61
# TextRank: ['factors', 'common', 'fraction', 'course', 'words']
#
# Cluster 62
# TextRank: ['relation', 'divisibility', 'divides', 'members', 'example']
#
# Cluster 63
# TextRank: ['returns', 'color', 'neighbor', 'calls', 'couple']
#
# Cluster 64
# TextRank: ['naught', 'minus', 'case', 'set', 'linear']
#
# Cluster 65
# TextRank: ['divides', 'integer', 'integers', 'multiple', 'case']
#
# Cluster 66
# TextRank: ['gcd', 'equation', 'factor', 'sides', 'minus']
#
# Cluster 67
# TextRank: ['color', 'neighbors', 'neighbor', 'node', 'parent']
#
# Cluster 68
# TextRank: ['neighbors', 'neighbor', 'queue', 'node', 'mix']
#
# Cluster 69
# TextRank: ['minus', 'linear', 'combination', 'equation', 'coefficients']
#
# Cluster 70
# TextRank: ['values', 'combination', 'linear', 'choice', 'numbers']
#
# Cluster 71
# TextRank: ['member', 'integers', 'set', 'gcd', 'positive']
#
# Cluster 72
# TextRank: ['set', 'gcd', 'member', 'positive', 'words']
#
# Cluster 73
# TextRank: ['gcd', 'number', 'remainder', 'mod', 'uniformity']
#
# Cluster 74
# TextRank: ['integers', 'integer', 'cq', 'xb', 'pair']
#
# Cluster 75
# TextRank: ['naught', 'case', 'bx', 'integers', 'cy']
#
# Cluster 76
# TextRank: ['prime', 'number', 'numbers', 'product', 'factors']
#
# Cluster 77
# TextRank: ['subset', 'relation', 'family', 'sets', 'example']
#
# Cluster 78
# TextRank: ['primes', 'prime', 'left', 'right', 'righthand']
#
# Cluster 79
# TextRank: ['primes', 'prime', 'pr', 'number', 'contradiction']
#
# Cluster 80
# TextRank: ['enumeration', 'consistent', 'numbers', 'predecessor', 'function']
#
# Cluster 81
# TextRank: ['successor', 'predecessor', 'immediate', 'relation', 'abc']
#
# Cluster 82
# TextRank: ['prime', 'pairs', 'jj', 'minimum', 'ordered']
#
# Cluster 83
# TextRank: ['lcm', 'gcd', 'mode', 'integers', 'pair']
#
# Cluster 84
# TextRank: ['meat', 'joint', 'meet', 'join', 'commutativity']
#
# Cluster 85
# TextRank: ['chain', 'length', 'subset', 'element', 'posit']
#
# Cluster 86
# TextRank: ['chain', 'antichain', 'elements', 'disjoint', 'antichains']
#
# Cluster 87
# TextRank: ['graph', 'colors', 'bipartite', 'color', 'graphs']
#
# Cluster 88
# TextRank: ['diagram', 'element', 'maximal', 'hassle', 'elements']
#
# Cluster 89
# TextRank: ['element', 'maximal', 'minimal', 'elements', 'phi']
#
# Cluster 90
# TextRank: ['relation', 'numbers', 'natural', 'pair', 'integers']
#
# Cluster 91
# TextRank: ['paradoxes', 'paradox', 'set', 'definition', 'abstract']
#
# Cluster 92
# TextRank: ['element', 'set', 'onetoone', 'isomorphism', 'example']
#
# Cluster 93
# TextRank: ['gcd', 'case', 'common', 'fb', 'factor']
#
# Cluster 94
# TextRank: ['singleton', 'set', 'subset', 'power', 'subsets']
#
# Cluster 95
# TextRank: ['set', 'omega', 'natural', 'numbers', 'inductive']
#
# Cluster 96
# TextRank: ['set', 'numbers', 'real', 'rational', 'natural']
#
# Cluster 97
# TextRank: ['set', 'power', 'axiom', 'axioms', 'existence']
#
# Cluster 98
# TextRank: ['theory', 'set', 'numbers', 'integers', 'domain']
#
# Cluster 99
# TextRank: ['addition', 'operations', 'integers', 'multiplication', 'set']
#
# Cluster 100
# TextRank: ['color', 'vertices', 'edge', 'edges', 'colors']
#
# Cluster 101
# TextRank: ['number', 'natural', 'set', 'finite', 'subset']
#
# Cluster 102
# TextRank: ['cardinality', 'set', 'numbers', 'cardinal', 'words']
#
# Cluster 103
# TextRank: ['capital', 'lcm', 'multiple', 'small', 'bd']
#
# Cluster 104
# TextRank: ['lcm', 'common', 'multiple', 'multiples', 'abc']
#
# Cluster 105
# TextRank: ['set', 'functions', 'function', 'superscript', 'fb']
#
# Cluster 106
# TextRank: ['function', 'domain', 'choice', 'image', 'axiom']
#
# Cluster 107
# TextRank: ['ordering', 'precedes', 'ordered', 'ntuple', 'relation']
#
# Cluster 108
# TextRank: ['color', 'vertices', 'colors', 'lets', 'alpha']
#
# Cluster 109
# TextRank: ['color', 'vertex', 'red', 'blue', 'colors']
#
# Cluster 110
# TextRank: ['precedes', 'relation', 'symbol', 'posit', 'fact']
#
# Cluster 111
# TextRank: ['words', 'subset', 'alpha', 'tk', 'set']
#
# Cluster 112
# TextRank: ['nominee', 'set', 'axiom', 'words', 'members']
#
# Cluster 113
# TextRank: ['lattice', 'axiom', 'sub', 'dm', 'distributive']
#
# Cluster 114
# TextRank: ['gcd', 'theorem', 'ax', 'words', 'integers']
#
# Cluster 115
# TextRank: ['pair', 'lattice', 'upper', 'set', 'bound']
#
# Cluster 116
# TextRank: ['graphs', 'graph', 'lets', 'isomorphism', 'examples']
#
# Cluster 117
# TextRank: ['strings', 'characters', 'length', 'sigma', 'alphabet']
#
# Cluster 118
# TextRank: ['string', 'length', 'strings', 'sigma', 'null']
#
# Cluster 119
# TextRank: ['vertex', 'red', 'onethird', 'ones', 'edge']
#
# Cluster 120
# TextRank: ['gcd', 'theorem', 'naught', 'common', 'class']
#
# Cluster 121
# TextRank: ['common', 'divisor', 'devices', 'words', 'bc']
#
# Cluster 122
# TextRank: ['colors', 'graph', 'number', 'color', 'graphs']
#
# Cluster 123
# TextRank: ['colors', 'degree', 'number', 'color', 'max']
#
# Cluster 124
# TextRank: ['phase', 'face', 'edges', 'number', 'region']
#
# Cluster 125
# TextRank: ['relation', 'relations', 'partial', 'order', 'ordering']
#
# Cluster 126
# TextRank: ['minus', 'quantity', 'formula', 'condition', 'corollary']
#
# Cluster 127
# TextRank: ['graph', 'peterson', 'cycle', 'edge', 'case']
#
# Cluster 128
# TextRank: ['cycle', 'hamiltonian', 'graph', 'vertex', 'cycles']
#
# Cluster 129
# TextRank: ['walk', 'vertices', 'path', 'sequence', 'graph']
#
# Cluster 130
# TextRank: ['euler', 'graph', 'circuit', 'vertex', 'eulers']
#
# Cluster 131
# TextRank: ['relation', 'relationship', 'definition', 'antisymmetric', 'case']
#
# Cluster 132
# TextRank: ['relation', 'example', 'posits', 'pairs', 'symbol']
#
# Cluster 133
# TextRank: ['relation', 'equivalence', 'partition', 'class', 'relationship']
#
# Cluster 134
# TextRank: ['path', 'paths', 'vertex', 'place', 'virtue']
#
# Cluster 135
# TextRank: ['summation', 'quantity', 'minus', 'terms', 'lot']
#
# Cluster 136
# TextRank: ['faces', 'summation', 'edges', 'fi', 'number']
#
# Cluster 137
# TextRank: ['vertex', 'edges', 'delta', 'number', 'vertices']
#
# Cluster 138
# TextRank: ['cycle', 'edge', 'uv', 'tree', 'edges']
#
# Cluster 139
# TextRank: ['vertex', 'vertices', 'collection', 'summation', 'nonzero']
#
# Cluster 140
# TextRank: ['vertex', 'number', 'times', 'following', 'total']
#
# Cluster 141
# TextRank: ['vertex', 'vertices', 'edges', 'starting', 'particular']
#
# Cluster 142
# TextRank: ['weight', 'edge', 'edges', 'cut', 'prime']
#
# Cluster 143
# TextRank: ['trees', 'kind', 'case', 'ways', 'choice']
#
# Cluster 144
# TextRank: ['vertex', 'opposite', 'diametrically', 'case', 'vertices']
#
# Cluster 145
# TextRank: ['vertex', 'vertices', 'entry', 'graph', 'dnc']
#
# Cluster 146
# TextRank: ['edges', 'number', 'su', 'size', 'sv']
#
# Cluster 147
# TextRank: ['edges', 'edge', 'boundary', 'number', 'face']
#
# Cluster 148
# TextRank: ['edge', 'edges', 'thing', 'diagonals', 'term']
#
# Cluster 149
# TextRank: ['tree', 'spanning', 'minimal', 'edge', 'graph']
#
# Cluster 150
# TextRank: ['trees', 'spanning', 'tree', 'number', 'graph']
#
# Cluster 151
# TextRank: ['star', 'cut', 'vertices', 'edge', 'capacity']
#
# Cluster 152
# TextRank: ['graph', 'regular', 'vertex', 'degree', 'example']
#
# Cluster 153
# TextRank: ['vertex', 'degree', 'vertices', 'graph', 'delta']
#
# Cluster 154
# TextRank: ['matrix', 'representation', 'adjacency', 'list', 'graph']
#
# Cluster 155
# TextRank: ['cycle', 'graph', 'original', 'parts', 'cycles']
#
# Cluster 156
# TextRank: ['tree', 'code', 'proofer', 'process', 'sequence']
#
# Cluster 157
# TextRank: ['node', 'proofer', 'code', 'internal', 'leaf']
#
# Cluster 158
# TextRank: ['cycle', 'edge', 'edges', 'cycles', 'remaining']
#
# Cluster 159
# TextRank: ['tree', 'sequence', 'unique', 'list', 'algorithm']
#
# Cluster 160
# TextRank: ['tree', 'edges', 'trees', 'edge', 'vertex']
#
# Cluster 161
# TextRank: ['tree', 'graph', 'vertex', 'trees', 'cycles']
#
# Cluster 162
# TextRank: ['cycle', 'vertices', 'walk', 'path', 'ravine']
#
# Cluster 163
# TextRank: ['cycle', 'cycles', 'graph', 'edges', 'red']
#
# Cluster 164
# TextRank: ['edges', 'cut', 'comma', 'kinds', 'st']
#
# Cluster 165
# TextRank: ['set', 'union', 'vertex', 'vertices', 'graph']
#
# Cluster 166
# TextRank: ['edge', 'edges', 'vertices', 'graph', 'set']
