# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from gensim import corpora, models
import spacy

df = pd.read_csv("../clustering/intermediate_data/clustered_embeddings.csv")
df = df[df["text"].notnull() & df["cluster"].notnull()]

grouped = df.groupby("cluster")["text"].apply(lambda x: " ".join(x)).reset_index()
grouped.columns = ["cluster", "combined_text"]

nlp = spacy.load("en_core_web_sm")

def apply_lda(texts, num_topics=1, num_words=5):
    tokenized = [[token.text.lower() for token in nlp(text) if token.is_alpha and not token.is_stop] for text in texts]
    dictionary = corpora.Dictionary(tokenized)
    corpus = [dictionary.doc2bow(text) for text in tokenized]
    lda_model = models.LdaModel(corpus, num_topics=num_topics, id2word=dictionary, passes=10)
    return [[word for word, prob in lda_model.show_topic(i, topn=num_words)] for i in range(num_topics)]

for i, row in grouped.iterrows():
    print(f"\nCluster {row['cluster']}")
    print("LDA:", apply_lda([row["combined_text"]])[0])
# Out:
# Cluster -1
# LDA: ['b', 'x', 'graph', 'okay', 'equal']
#
# Cluster 0
# LDA: ['person', 'hands', 'people', 'number', 'shook']
#
# Cluster 1
# LDA: ['hope', 'lecture', 'thank', 'class', 'modules']
#
# Cluster 2
# LDA: ['banks', 'island', 'bridge', 'islands', 'bank']
#
# Cluster 3
# LDA: ['s', 'size', 'neighbors', 'n', 'set']
#
# Cluster 4
# LDA: ['music', 'learn', 'lecture', 'graphs', 'graph']
#
# Cluster 5
# LDA: ['lecture', 'mathematics', 'theory', 'music', 'welcome']
#
# Cluster 6
# LDA: ['n', 'number', 'nt', 'edge', 'divide']
#
# Cluster 7
# LDA: ['node', 'leaf', 'neighbor', 'nodes', 'look']
#
# Cluster 8
# LDA: ['x', 'matching', 'perfect', 'prime', 's']
#
# Cluster 9
# LDA: ['matching', 'maximum', 'maximal', 'vertex', 'edges']
#
# Cluster 10
# LDA: ['matching', 'vertices', 'graph', 'seven', 'number']
#
# Cluster 11
# LDA: ['graph', 's', 'people', 'constructed', 'person']
#
# Cluster 12
# LDA: ['b', 'interval', 'zero', 'distance', 'point']
#
# Cluster 13
# LDA: ['prime', 'fraction', 'b', 'new', 'x']
#
# Cluster 14
# LDA: ['fraction', 'enumeration', 'second', 'position', 'new']
#
# Cluster 15
# LDA: ['bfs', 'vertex', 'search', 'graph', 'breadthfirst']
#
# Cluster 16
# LDA: ['dfs', 'okay', 'neighbor', 'ordering', 'bfs']
#
# Cluster 17
# LDA: ['dfs', 'vertex', 'color', 'recursive', 'stack']
#
# Cluster 18
# LDA: ['r', 'b', 'equal', 'qa', 'plus']
#
# Cluster 19
# LDA: ['r', 'algorithm', 'minus', 'division', 'gcd']
#
# Cluster 20
# LDA: ['vertices', 'v', 'order', 'okay', 'vertex']
#
# Cluster 21
# LDA: ['graph', 'planar', 'k', 'particular', 'look']
#
# Cluster 22
# LDA: ['queue', 'vertex', 'element', 'add', 'added']
#
# Cluster 23
# LDA: ['level', 'vertices', 'neighbors', 'neighbor', 'v']
#
# Cluster 24
# LDA: ['ancestor', 'common', 's', 'path', 'level']
#
# Cluster 25
# LDA: ['real', 'line', 'point', 'interval', 'semicircle']
#
# Cluster 26
# LDA: ['w', 'paths', 'okay', 'crossing', 'drawing']
#
# Cluster 27
# LDA: ['b', 'c', 'equal', 'power', 'n']
#
# Cluster 28
# LDA: ['set', 'hypothesis', 'theory', 'continuum', 'disproved']
#
# Cluster 29
# LDA: ['n', 'minus', 'x', 'elements', 's']
#
# Cluster 30
# LDA: ['minus', 'b', 'm', 'divides', 'c']
#
# Cluster 31
# LDA: ['numbers', 'thousand', 'belongs', 'e', 'number']
#
# Cluster 32
# LDA: ['come', 'point', 'okay', 'goes', 'place']
#
# Cluster 33
# LDA: ['graph', 'bipartite', 's', 'vertices', 'going']
#
# Cluster 34
# LDA: ['odd', 'graph', 'cycles', 'cycle', 'bipartite']
#
# Cluster 35
# LDA: ['k', 'divides', 'factorial', 'number', 'j']
#
# Cluster 36
# LDA: ['g', 'prime', 'graph', 'delta', 'colors']
#
# Cluster 37
# LDA: ['neighbors', 'v', 'minus', 'n', 'neighbor']
#
# Cluster 38
# LDA: ['m', 'j', 'eye', 'product', 'congruence']
#
# Cluster 39
# LDA: ['flow', 'okay', 's', 'edges', 'f']
#
# Cluster 40
# LDA: ['b', 'm', 'minus', 'congruent', 'divides']
#
# Cluster 41
# LDA: ['prime', 'r', 'q', 'equal', 'pair']
#
# Cluster 42
# LDA: ['squared', 'b', 'equal', 'square', 'k']
#
# Cluster 43
# LDA: ['m', 'congruent', 'ri', 'mod', 'j']
#
# Cluster 44
# LDA: ['p', 'divides', 'theorem', 'n', 'b']
#
# Cluster 45
# LDA: ['system', 'residue', 'm', 'phi', 'complete']
#
# Cluster 46
# LDA: ['prime', 'p', 'factorization', 'n', 'canonical']
#
# Cluster 47
# LDA: ['combination', 'linear', 'b', 'c', 'coefficients']
#
# Cluster 48
# LDA: ['set', 'count', 'members', 's', 'elements']
#
# Cluster 49
# LDA: ['neighbors', 'seven', 'okay', 'visited', 'goes']
#
# Cluster 50
# LDA: ['red', 'edge', 'edges', 'okay', 'blue']
#
# Cluster 51
# LDA: ['m', 'x', 'y', 'congruent', 'ax']
#
# Cluster 52
# LDA: ['modem', 'congruent', 'b', 'm', 'c']
#
# Cluster 53
# LDA: ['rational', 'x', 'number', 'set', 'numbers']
#
# Cluster 54
# LDA: ['coloring', 'greedy', 'algorithm', 'color', 'okay']
#
# Cluster 55
# LDA: ['y', 'x', 'minus', 'equal', 'plus']
#
# Cluster 56
# LDA: ['plus', 'root', 'b', 'c', 'd']
#
# Cluster 57
# LDA: ['norm', 'n', 'equal', 'root', 'product']
#
# Cluster 58
# LDA: ['k', 'l', 'lambda', 'kappa', 'cardinality']
#
# Cluster 59
# LDA: ['vertex', 'explored', 'colors', 'gray', 'black']
#
# Cluster 60
# LDA: ['vertex', 'dot', 'color', 'u', 'white']
#
# Cluster 61
# LDA: ['d', 'b', 'common', 'factors', 'cancel']
#
# Cluster 62
# LDA: ['relation', 'divides', 'divisibility', 'b', 'divide']
#
# Cluster 63
# LDA: ['black', 'okay', 'returns', 'white', 'color']
#
# Cluster 64
# LDA: ['minus', 'naught', 'z', 'b', 'x']
#
# Cluster 65
# LDA: ['divides', 'b', 'c', 'x', 'integer']
#
# Cluster 66
# LDA: ['gcd', 'm', 'g', 'divides', 'factor']
#
# Cluster 67
# LDA: ['color', 'neighbors', 'processed', 'gray', 'black']
#
# Cluster 68
# LDA: ['seven', 'processed', 'neighbor', 'neighbors', 'queue']
#
# Cluster 69
# LDA: ['minus', 'linear', 'plus', 'combination', 'equation']
#
# Cluster 70
# LDA: ['x', 'y', 'combination', 'linear', 'values']
#
# Cluster 71
# LDA: ['d', 'x', 'y', 'member', 'integers']
#
# Cluster 72
# LDA: ['b', 'set', 'positive', 'member', 'gcd']
#
# Cluster 73
# LDA: ['gcd', 'find', 'want', 'reduces', 'number']
#
# Cluster 74
# LDA: ['y', 'b', 'x', 'p', 'q']
#
# Cluster 75
# LDA: ['x', 'y', 'd', 'plus', 'naught']
#
# Cluster 76
# LDA: ['system', 'prime', 'number', 'n', 'expressed']
#
# Cluster 77
# LDA: ['subset', 'b', 'relation', 'equal', 'opposite']
#
# Cluster 78
# LDA: ['primes', 'r', 'prime', 's', 'right']
#
# Cluster 79
# LDA: ['n', 'primes', 'p', 'prime', 'pr']
#
# Cluster 80
# LDA: ['consistent', 'enumeration', 'g', 'gets', 'f']
#
# Cluster 81
# LDA: ['predecessor', 'successor', 'immediate', 'b', 'relation']
#
# Cluster 82
# LDA: ['prime', 'j', 'equal', 'bound', 'ordered']
#
# Cluster 83
# LDA: ['b', 'lcm', 'gcd', 'mode', 'integers']
#
# Cluster 84
# LDA: ['b', 'meet', 'join', 'c', 'meat']
#
# Cluster 85
# LDA: ['chain', 'consider', 'equal', 'posit', 'let']
#
# Cluster 86
# LDA: ['n', 'antichain', 'chain', 'disjoint', 'antichains']
#
# Cluster 87
# LDA: ['bipartite', 'graph', 'colors', 'graphs', 'color']
#
# Cluster 88
# LDA: ['diagram', 'maximal', 'element', 'hassle', 'f']
#
# Cluster 89
# LDA: ['element', 'maximal', 'minimal', 'elements', 'find']
#
# Cluster 90
# LDA: ['equal', 'numbers', 'b', 'natural', 'relation']
#
# Cluster 91
# LDA: ['paradoxes', 'paradox', 'set', 'definition', 'rid']
#
# Cluster 92
# LDA: ['b', 'set', 'c', 'element', 'd']
#
# Cluster 93
# LDA: ['b', 'coprime', 'gcd', 'let', 'g']
#
# Cluster 94
# LDA: ['singleton', 'set', 'containing', 'power', 'subset']
#
# Cluster 95
# LDA: ['set', 'natural', 'defined', 'omega', 'numbers']
#
# Cluster 96
# LDA: ['countable', 'set', 'numbers', 'real', 'let']
#
# Cluster 97
# LDA: ['set', 'x', 'axiom', 'power', 'y']
#
# Cluster 98
# LDA: ['theory', 'set', 'numbers', 'embed', 'rational']
#
# Cluster 99
# LDA: ['addition', 'defined', 'n', 'set', 'integers']
#
# Cluster 100
# LDA: ['color', 'vertices', 'edges', 'edge', 'colors']
#
# Cluster 101
# LDA: ['natural', 'equinumerous', 'number', 'set', 'finite']
#
# Cluster 102
# LDA: ['cardinality', 'set', 'b', 'cardinal', 'numbers']
#
# Cluster 103
# LDA: ['l', 'd', 'capital', 'b', 'lcm']
#
# Cluster 104
# LDA: ['b', 'l', 'common', 'lcm', 'multiple']
#
# Cluster 105
# LDA: ['set', 'superscript', 'function', 'b', 'functions']
#
# Cluster 106
# LDA: ['x', 'f', 'b', 'function', 'belongs']
#
# Cluster 107
# LDA: ['b', 'equal', 'precedes', 'ordering', 'ordered']
#
# Cluster 108
# LDA: ['color', 'x', 'unused', 'y', 'colors']
#
# Cluster 109
# LDA: ['color', 'given', 'vertex', 'red', 'blue']
#
# Cluster 110
# LDA: ['b', 'precedes', 'x', 'equal', 'symbol']
#
# Cluster 111
# LDA: ['y', 'x', 'z', 'belongs', 't']
#
# Cluster 112
# LDA: ['nominee', 'x', 'y', 'axiom', 'set']
#
# Cluster 113
# LDA: ['lattice', 'distributive', 'l', 'axiom', 'sub']
#
# Cluster 114
# LDA: ['gcd', 'b', 'theorem', 'plus', 'g']
#
# Cluster 115
# LDA: ['bound', 'lower', 'upper', 'b', 'greatest']
#
# Cluster 116
# LDA: ['graphs', 'isomorphic', 'graph', 'lets', 'look']
#
# Cluster 117
# LDA: ['strings', 'length', 'characters', 'b', 'number']
#
# Cluster 118
# LDA: ['string', 'length', 'sigma', 'star', 'null']
#
# Cluster 119
# LDA: ['went', 'thousand', 'heads', 'vertex', 'visited']
#
# Cluster 120
# LDA: ['g', 'b', 'c', 'gcd', 'd']
#
# Cluster 121
# LDA: ['common', 'divisor', 'b', 'c', 'd']
#
# Cluster 122
# LDA: ['graph', 'colors', 'color', 'number', 'required']
#
# Cluster 123
# LDA: ['degree', 'colors', 'number', 'max', 'required']
#
# Cluster 124
# LDA: ['phase', 'going', 'face', 'region', 'edges']
#
# Cluster 125
# LDA: ['relation', 'ordering', 'partial', 'partially', 'order']
#
# Cluster 126
# LDA: ['minus', 'e', 'v', 'equal', 'f']
#
# Cluster 127
# LDA: ['graph', 'peterson', 'nt', 'cycle', 'okay']
#
# Cluster 128
# LDA: ['cycle', 'hamiltonian', 'vertex', 'graph', 'look']
#
# Cluster 129
# LDA: ['walk', 'vertices', 'path', 'okay', 'repeated']
#
# Cluster 130
# LDA: ['euler', 'graph', 'circuit', 'theorem', 'eulers']
#
# Cluster 131
# LDA: ['equal', 'b', 'relation', 'c', 'relationship']
#
# Cluster 132
# LDA: ['relation', 'consider', 'let', 'equal', 'b']
#
# Cluster 133
# LDA: ['equivalence', 'relation', 'connected', 'x', 'partition']
#
# Cluster 134
# LDA: ['path', 'connected', 'paths', 'okay', 'y']
#
# Cluster 135
# LDA: ['f', 'e', 'going', 'v', 'summation']
#
# Cluster 136
# LDA: ['f', 'summation', 'equal', 'faces', 'going']
#
# Cluster 137
# LDA: ['vertex', 'edges', 'v', 'number', 'delta']
#
# Cluster 138
# LDA: ['cycle', 'uv', 'edge', 'going', 'add']
#
# Cluster 139
# LDA: ['vertex', 't', 's', 'contains', 'v']
#
# Cluster 140
# LDA: ['vertex', 'okay', 'times', 'left', 'number']
#
# Cluster 141
# LDA: ['vertex', 'vertices', 'okay', 'starting', 'start']
#
# Cluster 142
# LDA: ['weight', 'edge', 'cut', 'e', 'edges']
#
# Cluster 143
# LDA: ['diagonal', 'include', 'choose', 'okay', 'trees']
#
# Cluster 144
# LDA: ['v', 'vertex', 'diametrically', 'opposite', 'joined']
#
# Cluster 145
# LDA: ['connected', 'd', 'b', 'c', 'vertex']
#
# Cluster 146
# LDA: ['edges', 'minus', 'su', 'sv', 'number']
#
# Cluster 147
# LDA: ['edges', 'edge', 'boundary', 'e', 'f']
#
# Cluster 148
# LDA: ['edge', 'add', 'okay', 'going', 'edges']
#
# Cluster 149
# LDA: ['spanning', 'tree', 'minimal', 'edge', 'okay']
#
# Cluster 150
# LDA: ['spanning', 'trees', 'n', 'tree', 'k']
#
# Cluster 151
# LDA: ['star', 'b', 'cut', 'vertices', 's']
#
# Cluster 152
# LDA: ['graph', 'regular', 'degree', 'vertex', 'look']
#
# Cluster 153
# LDA: ['vertex', 'degree', 'okay', 'vertices', 'going']
#
# Cluster 154
# LDA: ['matrix', 'representation', 'adjacency', 'list', 'c']
#
# Cluster 155
# LDA: ['graph', 'cycle', 'original', 'parts', 'cycles']
#
# Cluster 156
# LDA: ['proofer', 'tree', 'code', 'generating', 'particular']
#
# Cluster 157
# LDA: ['node', 'proofer', 'code', 'internal', 'leaf']
#
# Cluster 158
# LDA: ['cycle', 'edge', 'added', 'edges', 'e']
#
# Cluster 159
# LDA: ['tree', 'unique', 'sequence', 'look', 'n']
#
# Cluster 160
# LDA: ['tree', 'n', 'edges', 'edge', 'disjoint']
#
# Cluster 161
# LDA: ['tree', 'graph', 'vertex', 'connected', 'trees']
#
# Cluster 162
# LDA: ['cycle', 'vertices', 'ok', 'okay', 'path']
#
# Cluster 163
# LDA: ['cycle', 'okay', 'cycles', 'graph', 'nt']
#
# Cluster 164
# LDA: ['edges', 'b', 'cut', 's', 't']
#
# Cluster 165
# LDA: ['set', 'vertex', 'x', 'union', 'y']
#
# Cluster 166
# LDA: ['edge', 'edges', 'b', 'set', 'okay']
