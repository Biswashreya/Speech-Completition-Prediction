# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from gensim import corpora, models
import spacy

df = pd.read_csv("../clustering/intermediate_data/clustered_embeddings.csv")
df = df[df["text"].notnull() & df["cluster"].notnull()]

grouped = df.groupby("cluster")["text"].apply(lambda x: " ".join(x)).reset_index()
grouped.columns = ["cluster", "combined_text"]

nlp = spacy.load("en_core_web_sm")

def apply_lda(texts, num_topics=1, num_words=5):
    tokenized = [[token.text.lower() for token in nlp(text) if token.is_alpha and not token.is_stop] for text in texts]
    dictionary = corpora.Dictionary(tokenized)
    corpus = [dictionary.doc2bow(text) for text in tokenized]
    lda_model = models.LdaModel(corpus, num_topics=num_topics, id2word=dictionary, passes=10)
    return [[word for word, prob in lda_model.show_topic(i, topn=num_words)] for i in range(num_topics)]

for i, row in grouped.iterrows():
    print(f"\nCluster {row['cluster']}")
    print("LDA:", apply_lda([row["combined_text"]])[0])
# Out:
# Cluster -1
# LDA: ['n', 'set', 's', 'p', 'b']
#
# Cluster 0
# LDA: ['come', 'mom', 'dad', 'nt', 'comes']
#
# Cluster 1
# LDA: ['factorial', 'ways', 'letters', 'vowels', 'number']
#
# Cluster 2
# LDA: ['x', 'rubiks', 'cube', 'solve', 'number']
#
# Cluster 3
# LDA: ['root', 'square', 's', 'p', 'rational']
#
# Cluster 4
# LDA: ['number', 'b', 'possible', 'true', 'statement']
#
# Cluster 5
# LDA: ['right', 'question', 'answer', 'wrong', 'marks']
#
# Cluster 6
# LDA: ['b', 'divisor', 'divisors', 'possibilities', 'divides']
#
# Cluster 7
# LDA: ['square', 'number', 'p', 'implies', 'q']
#
# Cluster 8
# LDA: ['intelligent', 'michael', 'ram', 'true', 'p']
#
# Cluster 9
# LDA: ['rich', 'happy', 'true', 'person', 'poor']
#
# Cluster 10
# LDA: ['cantor', 'set', 'theory', 'numbers', 'concept']
#
# Cluster 11
# LDA: ['flavors', 'ways', 'different', 'vanilla', 'second']
#
# Cluster 12
# LDA: ['l', 'parallel', 'line', 'lines', 'relation']
#
# Cluster 13
# LDA: ['come', 'ways', 'people', 'party', 'way']
#
# Cluster 14
# LDA: ['girls', 'choose', 'factorial', 'team', 'ways']
#
# Cluster 15
# LDA: ['statement', 'true', 'statements', 'false', 'india']
#
# Cluster 16
# LDA: ['person', 'people', 'lets', 'come', 's']
#
# Cluster 17
# LDA: ['factorial', 'number', 'seconds', 'huge', 'happens']
#
# Cluster 18
# LDA: ['laws', 'understand', 'supposed', 'state', 'let']
#
# Cluster 19
# LDA: ['combinations', 'permutations', 'speak', 'problems', 'order']
#
# Cluster 20
# LDA: ['logic', 'mathematical', 'statements', 'conclude', 'going']
#
# Cluster 21
# LDA: ['problem', 'video', 'understand', 'read', 'solve']
#
# Cluster 22
# LDA: ['compliment', 'intersection', 'law', 'morgans', 'de']
#
# Cluster 23
# LDA: ['counting', 'count', 'tear', 'point', 'pile']
#
# Cluster 24
# LDA: ['related', 'people', 'cluster', 'born', 'lets']
#
# Cluster 25
# LDA: ['people', 'relation', 'knows', 'b', 'set']
#
# Cluster 26
# LDA: ['ways', 'objects', 'place', 'answer', 'c']
#
# Cluster 27
# LDA: ['blue', 'n', 'plus', 'squares', 'elements']
#
# Cluster 28
# LDA: ['set', 'power', 'n', 'elements', 'subsets']
#
# Cluster 29
# LDA: ['b', 'union', 'set', 'elements', 'number']
#
# Cluster 30
# LDA: ['s', 'c', 'union', 'intersection', 'triangle']
#
# Cluster 31
# LDA: ['b', 'complement', 'intersection', 'x', 'belongs']
#
# Cluster 32
# LDA: ['set', 'subset', 'containing', 'question', 'element']
#
# Cluster 33
# LDA: ['set', 'phi', 'containing', 'element', 'true']
#
# Cluster 34
# LDA: ['square', 'choose', 'n', 'numbers', 'triangle']
#
# Cluster 35
# LDA: ['knows', 's', 'knowledgeable', 'status', 'fact']
#
# Cluster 36
# LDA: ['b', 'know', 'friends', 'd', 'knows']
#
# Cluster 37
# LDA: ['b', 'questions', 'answer', 'possibility', 'ways']
#
# Cluster 38
# LDA: ['choices', 'wants', 'alice', 'magazine', 'newspaper']
#
# Cluster 39
# LDA: ['factorial', 'ways', 'ae', 'c', 'bc']
#
# Cluster 40
# LDA: ['people', 'picture', 'ways', 'pictures', 'c']
#
# Cluster 41
# LDA: ['n', 'minus', 'diagonals', 'equal', 'number']
#
# Cluster 42
# LDA: ['relation', 's', 'set', 'partition', 'equivalence']
#
# Cluster 43
# LDA: ['n', 'parenthesis', 'valid', 'branches', 'way']
#
# Cluster 44
# LDA: ['catalan', 'numbers', 'chapter', 'parenthesis', 'n']
#
# Cluster 45
# LDA: ['rs', 'u', 'right', 'number', 'r']
#
# Cluster 46
# LDA: ['diagonal', 'ways', 'right', 'reach', 'possibilities']
#
# Cluster 47
# LDA: ['ab', 'square', 'b', 'cube', 'pick']
#
# Cluster 48
# LDA: ['pick', 'cells', 'b', 'cell', 'ways']
#
# Cluster 49
# LDA: ['n', 'factorial', 'minus', 'r', 'plus']
#
# Cluster 50
# LDA: ['x', 'set', 'integer', 'positive', 'write']
#
# Cluster 51
# LDA: ['set', 'finite', 's', 'list', 'numbers']
#
# Cluster 52
# LDA: ['relation', 'representation', 'graphical', 'matrix', 'easy']
#
# Cluster 53
# LDA: ['factorial', 'n', 'minus', 'r', 'choose']
#
# Cluster 54
# LDA: ['n', 'objects', 'factorial', 'minus', 'choosing']
#
# Cluster 55
# LDA: ['cross', 'b', 's', 'comma', 'set']
#
# Cluster 56
# LDA: ['true', 'q', 'p', 'weather', 'today']
#
# Cluster 57
# LDA: ['column', 'row', 'knows', 'e', 'b']
#
# Cluster 58
# LDA: ['n', 'x', 'theorem', 'plus', 'binomial']
#
# Cluster 59
# LDA: ['choose', 'plus', 'x', 'cube', 'minus']
#
# Cluster 60
# LDA: ['relations', 'n', 'question', 'total', 's']
#
# Cluster 61
# LDA: ['b', 'related', 'divided', 'leave', 'remainder']
#
# Cluster 62
# LDA: ['relation', 'r', 'b', 'belongs', 'symmetric']
#
# Cluster 63
# LDA: ['minus', 'r', 'x', 'power', 'term']
#
# Cluster 64
# LDA: ['term', 'n', 'middle', 'plus', 'x']
#
# Cluster 65
# LDA: ['diagonal', 'entries', 'zone', 'entry', 'corresponding']
#
# Cluster 66
# LDA: ['matrix', 'm', 'entry', 'equal', 'relation']
#
# Cluster 67
# LDA: ['relation', 'antisymmetric', 'b', 'present', 'let']
#
# Cluster 68
# LDA: ['boolean', 'assignment', 'try', 'expression', 'makes']
#
# Cluster 69
# LDA: ['p', 'q', 'xor', 'column', 'r']
#
# Cluster 70
# LDA: ['q', 'p', 'law', 'true', 'statement']
#
# Cluster 71
# LDA: ['p', 'statement', 'negation', 'q', 'complement']
#
# Cluster 72
# LDA: ['true', 'p', 'q', 'r', 'implies']
#
# Cluster 73
# LDA: ['p', 'q', 'implies', 'truthtable', 'true']
