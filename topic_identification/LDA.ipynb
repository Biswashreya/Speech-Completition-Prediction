# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from gensim import corpora, models
import spacy

df = pd.read_csv("../clustering/intermediate_data/clustered_embeddings.csv")
df = df[df["text"].notnull() & df["cluster"].notnull()]

grouped = df.groupby("cluster")["text"].apply(lambda x: " ".join(x)).reset_index()
grouped.columns = ["cluster", "combined_text"]

nlp = spacy.load("en_core_web_sm")

def apply_lda(texts, num_topics=1, num_words=5):
    tokenized = [[token.text.lower() for token in nlp(text) if token.is_alpha and not token.is_stop] for text in texts]
    dictionary = corpora.Dictionary(tokenized)
    corpus = [dictionary.doc2bow(text) for text in tokenized]
    lda_model = models.LdaModel(corpus, num_topics=num_topics, id2word=dictionary, passes=10)
    return [[word for word, prob in lda_model.show_topic(i, topn=num_words)] for i in range(num_topics)]

for i, row in grouped.iterrows():
    print(f"\nCluster {row['cluster']}")
    print("LDA:", apply_lda([row["combined_text"]])[0])
# Out:
# Cluster -1
# LDA: ['b', 'x', 'graph', 'equal', 'edge']
#
# Cluster 0
# LDA: ['person', 'hands', 'people', 'number', 'shook']
#
# Cluster 1
# LDA: ['s', 'size', 'neighbors', 'n', 'set']
#
# Cluster 2
# LDA: ['matching', 'graph', 'vertices', 'perfect', 'x']
#
# Cluster 3
# LDA: ['music', 'lecture', 'learn', 'graphs', 'graph']
#
# Cluster 4
# LDA: ['lecture', 'mathematics', 'theory', 'music', 'welcome']
#
# Cluster 5
# LDA: ['banks', 'island', 'islands', 'bank', 'bridge']
#
# Cluster 6
# LDA: ['graph', 's', 'person', 'people', 'vertex']
#
# Cluster 7
# LDA: ['b', 'interval', 'point', 'zero', 'distance']
#
# Cluster 8
# LDA: ['graph', 'bipartite', 's', 'vertices', 'y']
#
# Cluster 9
# LDA: ['neighbors', 'v', 'minus', 'n', 'neighbor']
#
# Cluster 10
# LDA: ['vertices', 'order', 'v', 'lets', 'vertex']
#
# Cluster 11
# LDA: ['level', 'neighbors', 'common', 'ancestor', 'look']
#
# Cluster 12
# LDA: ['okay', 'going', 'appear', 'ones', 'positive']
#
# Cluster 13
# LDA: ['numbers', 'thousand', 'belongs', 'number', 'e']
#
# Cluster 14
# LDA: ['bfs', 'vertex', 'search', 'graph', 'breadthfirst']
#
# Cluster 15
# LDA: ['dfs', 'vertex', 'color', 'recursive', 'stack']
#
# Cluster 16
# LDA: ['r', 'b', 'equal', 'qa', 'plus']
#
# Cluster 17
# LDA: ['rational', 'x', 'number', 'set', 'cut']
#
# Cluster 18
# LDA: ['real', 'line', 'point', 'interval', 'semicircle']
#
# Cluster 19
# LDA: ['fraction', 'new', 'position', 'enumeration', 'b']
#
# Cluster 20
# LDA: ['odd', 'graph', 'cycles', 'cycle', 'bipartite']
#
# Cluster 21
# LDA: ['w', 'paths', 'okay', 'drawing', 'c']
#
# Cluster 22
# LDA: ['queue', 'vertex', 'added', 'element', 'add']
#
# Cluster 23
# LDA: ['set', 'hypothesis', 'theory', 'continuum', 'disproved']
#
# Cluster 24
# LDA: ['phase', 'going', 'face', 'region', 'edges']
#
# Cluster 25
# LDA: ['prime', 'r', 'q', 'equal', 'ordered']
#
# Cluster 26
# LDA: ['g', 'prime', 'graph', 'delta', 'colors']
#
# Cluster 27
# LDA: ['neighbors', 'seven', 'color', 'black', 'processed']
#
# Cluster 28
# LDA: ['squared', 'b', 'equal', 'square', 'k']
#
# Cluster 29
# LDA: ['come', 'goes', 'okay', 'standard', 'way']
#
# Cluster 30
# LDA: ['b', 'plus', 'root', 'c', 'form']
#
# Cluster 31
# LDA: ['m', 'j', 'eye', 'product', 'congruence']
#
# Cluster 32
# LDA: ['b', 'power', 'c', 'n', 'equal']
#
# Cluster 33
# LDA: ['p', 'divides', 'theorem', 'n', 'b']
#
# Cluster 34
# LDA: ['women', 'daughter', 'elements', 'mother', 'grandmother']
#
# Cluster 35
# LDA: ['k', 'divides', 'factorial', 'number', 'j']
#
# Cluster 36
# LDA: ['bipartite', 'graph', 'colors', 'graphs', 'color']
#
# Cluster 37
# LDA: ['m', 'x', 'y', 'congruent', 'modulo']
#
# Cluster 38
# LDA: ['system', 'residue', 'm', 'phi', 'complete']
#
# Cluster 39
# LDA: ['d', 'b', 'common', 'factors', 'cancel']
#
# Cluster 40
# LDA: ['minus', 'b', 'm', 'divides', 'c']
#
# Cluster 41
# LDA: ['graph', 'planar', 'k', 'particular', 'look']
#
# Cluster 42
# LDA: ['set', 's', 'count', 'members', 'enumeration']
#
# Cluster 43
# LDA: ['b', 'm', 'congruent', 'integers', 'minus']
#
# Cluster 44
# LDA: ['b', 'congruent', 'modem', 'm', 'c']
#
# Cluster 45
# LDA: ['singleton', 'set', 'containing', 'subset', 'find']
#
# Cluster 46
# LDA: ['n', 'minus', 'x', 'lists', 's']
#
# Cluster 47
# LDA: ['node', 'leaf', 'neighbor', 'nodes', 'valued']
#
# Cluster 48
# LDA: ['prime', 'x', 'y', 'n', 'okay']
#
# Cluster 49
# LDA: ['prime', 'bound', 'j', 'equal', 'lower']
#
# Cluster 50
# LDA: ['vertex', 'dot', 'color', 'white', 'u']
#
# Cluster 51
# LDA: ['vertex', 'explored', 'means', 'black', 'white']
#
# Cluster 52
# LDA: ['k', 'colors', 'regular', 'graph', 'color']
#
# Cluster 53
# LDA: ['gcd', 'find', 'exponent', 'reduces', 'want']
#
# Cluster 54
# LDA: ['predecessor', 'successor', 'immediate', 'b', 'relation']
#
# Cluster 55
# LDA: ['y', 'x', 'minus', 'equal', 'defined']
#
# Cluster 56
# LDA: ['norm', 'n', 'equal', 'root', 'greater']
#
# Cluster 57
# LDA: ['paradoxes', 'set', 'paradox', 'x', 'precise']
#
# Cluster 58
# LDA: ['minus', 'linear', 'plus', 'combination', 'equation']
#
# Cluster 59
# LDA: ['x', 'y', 'combination', 'values', 'linear']
#
# Cluster 60
# LDA: ['b', 'v', 'set', 'f', 'mapping']
#
# Cluster 61
# LDA: ['consistent', 'enumeration', 'gets', 'g', 'f']
#
# Cluster 62
# LDA: ['f', 'e', 'going', 'v', 'summation']
#
# Cluster 63
# LDA: ['algorithm', 'step', 'iterative', 'algorithms', 'look']
#
# Cluster 64
# LDA: ['coloring', 'greedy', 'algorithm', 'color', 'okay']
#
# Cluster 65
# LDA: ['vertices', 'color', 'edge', 'edges', 'colors']
#
# Cluster 66
# LDA: ['f', 'summation', 'equal', 'e', 'faces']
#
# Cluster 67
# LDA: ['minus', 'e', 'v', 'equal', 'f']
#
# Cluster 68
# LDA: ['axiom', 'set', 'x', 'says', 'pairing']
#
# Cluster 69
# LDA: ['chain', 'n', 'antichain', 'element', 'elements']
#
# Cluster 70
# LDA: ['element', 'maximal', 'elements', 'minimal', 'diagram']
#
# Cluster 71
# LDA: ['coloring', 'vertex', 'function', 'set', 'define']
#
# Cluster 72
# LDA: ['colors', 'number', 'graph', 'color', 'degree']
#
# Cluster 73
# LDA: ['red', 'edge', 'edges', 'okay', 'blue']
#
# Cluster 74
# LDA: ['member', 'b', 'positive', 'set', 'd']
#
# Cluster 75
# LDA: ['graph', 'colored', 'colors', 'delta', 'color']
#
# Cluster 76
# LDA: ['divides', 'b', 'c', 'integer', 'x']
#
# Cluster 77
# LDA: ['b', 'c', 'integers', 'x', 'multiple']
#
# Cluster 78
# LDA: ['r', 'division', 'algorithm', 'pair', 'ordered']
#
# Cluster 79
# LDA: ['r', 'gcd', 'minus', 'naught', 'q']
#
# Cluster 80
# LDA: ['minus', 'naught', 'd', 'x', 'z']
#
# Cluster 81
# LDA: ['y', 'x', 'b', 'plus', 'integers']
#
# Cluster 82
# LDA: ['primes', 'r', 'prime', 'p', 'divide']
#
# Cluster 83
# LDA: ['color', 'okay', 'blue', 'red', 'lets']
#
# Cluster 84
# LDA: ['prime', 'p', 'n', 'canonical', 'factorization']
#
# Cluster 85
# LDA: ['countable', 'set', 'numbers', 'real', 'rational']
#
# Cluster 86
# LDA: ['subset', 'b', 'relation', 'let', 'set']
#
# Cluster 87
# LDA: ['n', 'primes', 'larger', 'log', 'number']
#
# Cluster 88
# LDA: ['color', 'given', 'vertex', 'red', 'blue']
#
# Cluster 89
# LDA: ['color', 'x', 'unused', 'vertices', 'colors']
#
# Cluster 90
# LDA: ['set', 'theory', 'numbers', 'embed', 'consider']
#
# Cluster 91
# LDA: ['b', 'lcm', 'gcd', 'mode', 'integers']
#
# Cluster 92
# LDA: ['p', 'prime', 'pr', 'n', 'larger']
#
# Cluster 93
# LDA: ['prime', 'system', 'p', 'number', 'numbers']
#
# Cluster 94
# LDA: ['relation', 'divides', 'divisibility', 'b', 'divide']
#
# Cluster 95
# LDA: ['operations', 'set', 'addition', 'defined', 'integers']
#
# Cluster 96
# LDA: ['n', 'm', 'addition', 'sum', 'plus']
#
# Cluster 97
# LDA: ['set', 'natural', 'defined', 'numbers', 'omega']
#
# Cluster 98
# LDA: ['x', 'y', 'set', 'belongs', 'z']
#
# Cluster 99
# LDA: ['power', 'set', 'b', 'look', 'defined']
#
# Cluster 100
# LDA: ['sigma', 'order', 'star', 'enumerate', 'strings']
#
# Cluster 101
# LDA: ['strings', 'length', 'string', 'sigma', 'characters']
#
# Cluster 102
# LDA: ['k', 'l', 'lambda', 'kappa', 'cardinality']
#
# Cluster 103
# LDA: ['b', 'x', 'belong', 'belongs', 'hand']
#
# Cluster 104
# LDA: ['x', 'f', 'function', 'b', 'belongs']
#
# Cluster 105
# LDA: ['b', 'coprime', 'let', 'g', 'prime']
#
# Cluster 106
# LDA: ['natural', 'number', 'equinumerous', 'set', 'finite']
#
# Cluster 107
# LDA: ['cardinality', 'set', 'cardinal', 'b', 'equal']
#
# Cluster 108
# LDA: ['number', 'edges', 'vertex', 'vertices', 'v']
#
# Cluster 109
# LDA: ['b', 'meet', 'join', 'c', 'meat']
#
# Cluster 110
# LDA: ['graph', 'number', 'edges', 'smaller', 'edge']
#
# Cluster 111
# LDA: ['lattice', 'distributive', 'l', 'axiom', 'dm']
#
# Cluster 112
# LDA: ['bound', 'upper', 'lower', 'b', 'greatest']
#
# Cluster 113
# LDA: ['l', 'b', 'common', 'lcm', 'c']
#
# Cluster 114
# LDA: ['l', 'd', 'capital', 'lcm', 'b']
#
# Cluster 115
# LDA: ['common', 'b', 'divisor', 'c', 'd']
#
# Cluster 116
# LDA: ['relation', 'symmetric', 'minus', 'antisymmetric', 'equal']
#
# Cluster 117
# LDA: ['b', 'equal', 'precedes', 'ordered', 'ntuple']
#
# Cluster 118
# LDA: ['graph', 'regular', 'degree', 'vertex', 'look']
#
# Cluster 119
# LDA: ['b', 'relation', 'equal', 'consider', 'ordered']
#
# Cluster 120
# LDA: ['relation', 'ordering', 'partial', 'partially', 'set']
#
# Cluster 121
# LDA: ['numbers', 'equal', 'natural', 'relation', 'b']
#
# Cluster 122
# LDA: ['equal', 'b', 'relation', 'c', 'relationship']
#
# Cluster 123
# LDA: ['g', 'c', 'd', 'b', 'divides']
#
# Cluster 124
# LDA: ['c', 'b', 'gcd', 'theorem', 'common']
#
# Cluster 125
# LDA: ['vertex', 'degree', 'k', 'maximum', 'vn']
#
# Cluster 126
# LDA: ['vertex', 'degree', 'okay', 'vertices', 'equal']
#
# Cluster 127
# LDA: ['graphs', 'isomorphic', 'graph', 'lets', 'isomorphism']
#
# Cluster 128
# LDA: ['diagonal', 'include', 'choose', 'trees', 'okay']
#
# Cluster 129
# LDA: ['star', 'b', 'cut', 'vertices', 's']
#
# Cluster 130
# LDA: ['spanning', 'trees', 'n', 'tree', 'k']
#
# Cluster 131
# LDA: ['units', 'okay', 'flow', 'additional', 'new']
#
# Cluster 132
# LDA: ['cycle', 'uv', 'edge', 'going', 'add']
#
# Cluster 133
# LDA: ['saturated', 'edge', 's', 'look', 'flow']
#
# Cluster 134
# LDA: ['minus', 'edges', 'su', 'sv', 'number']
#
# Cluster 135
# LDA: ['edges', 'edge', 'boundary', 'number', 'e']
#
# Cluster 136
# LDA: ['matrix', 'list', 'representation', 'adjacency', 'graph']
#
# Cluster 137
# LDA: ['code', 'proofer', 'node', 'tree', 'internal']
#
# Cluster 138
# LDA: ['vertex', 't', 's', 'contains', 'f']
#
# Cluster 139
# LDA: ['capacity', 'edge', 'edges', 'operating', 'c']
#
# Cluster 140
# LDA: ['went', 'path', 'vertex', 'red', 'visited']
#
# Cluster 141
# LDA: ['graph', 'residual', 'flow', 'f', 'okay']
#
# Cluster 142
# LDA: ['capacity', 'residual', 'flow', 'okay', 'edge']
#
# Cluster 143
# LDA: ['tree', 'sequence', 'unique', 'n', 'look']
#
# Cluster 144
# LDA: ['vertex', 'okay', 'times', 'left', 'number']
#
# Cluster 145
# LDA: ['vertex', 'vertices', 'starting', 'okay', 'come']
#
# Cluster 146
# LDA: ['euler', 'circuit', 'graph', 'vertex', 'degree']
#
# Cluster 147
# LDA: ['edges', 's', 'outgoing', 'sum', 'f']
#
# Cluster 148
# LDA: ['euler', 'graph', 'cycle', 'theorem', 'path']
#
# Cluster 149
# LDA: ['connected', 'theorem', 'eulers', 'graph', 'euler']
#
# Cluster 150
# LDA: ['weight', 'e', 'prime', 't', 'edge']
#
# Cluster 151
# LDA: ['edge', 'cut', 'weight', 'edges', 'okay']
#
# Cluster 152
# LDA: ['cycle', 'hamiltonian', 'vertex', 'graph', 'look']
#
# Cluster 153
# LDA: ['graph', 'peterson', 'nt', 'cycle', 'g']
#
# Cluster 154
# LDA: ['edge', 'graph', 'edges', 'corresponding', 'vertices']
#
# Cluster 155
# LDA: ['edge', 'f', 'flow', 'sum', 'e']
#
# Cluster 156
# LDA: ['n', 'trees', 'minus', 'disjoint', 'edges']
#
# Cluster 157
# LDA: ['connected', 'equivalence', 'relation', 'x', 'class']
#
# Cluster 158
# LDA: ['flow', 'okay', 'particular', 'theorem', 'better']
#
# Cluster 159
# LDA: ['flow', 'cut', 'capacity', 'maximum', 'okay']
#
# Cluster 160
# LDA: ['set', 'vertex', 'x', 'union', 'y']
#
# Cluster 161
# LDA: ['flow', 'node', 'internal', 'equal', 'nodes']
#
# Cluster 162
# LDA: ['tree', 'edge', 'e', 'ok', 'edges']
#
# Cluster 163
# LDA: ['tree', 'vertex', 'graph', 'connected', 'trees']
#
# Cluster 164
# LDA: ['v', 'diametrically', 'opposite', 'vertex', 'joined']
#
# Cluster 165
# LDA: ['edge', 'edges', 'going', 'okay', 'add']
#
# Cluster 166
# LDA: ['edge', 'edges', 'b', 's', 'okay']
#
# Cluster 167
# LDA: ['tree', 'spanning', 'minimal', 'okay', 'graph']
#
# Cluster 168
# LDA: ['minimal', 'edge', 'spanning', 'tree', 'cut']
#
# Cluster 169
# LDA: ['flow', 'edges', 'value', 's', 'red']
#
# Cluster 170
# LDA: ['f', 'flow', 'value', 's', 'equal']
#
# Cluster 171
# LDA: ['connected', 'b', 'vertex', 'd', 'c']
#
# Cluster 172
# LDA: ['connected', 'd', 'c', 'b', 'look']
#
# Cluster 173
# LDA: ['walk', 'vertices', 'repeated', 'path', 'graph']
#
# Cluster 174
# LDA: ['path', 'walk', 'let', 'okay', 'starting']
#
# Cluster 175
# LDA: ['cycle', 'edge', 'e', 'b', 'edges']
#
# Cluster 176
# LDA: ['cycle', 'okay', 'edges', 'cycles', 'red']
#
# Cluster 177
# LDA: ['graph', 'cycle', 'original', 'parts', 'surely']
#
# Cluster 178
# LDA: ['cycle', 'okay', 'graph', 'vertices', 'ok']
