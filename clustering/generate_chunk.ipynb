# %%
import pandas as pd
import os
import math
import json

INPUT_CSV = ""
OUTPUT_DIR = ""
CHUNK_SIZE = 40

os.makedirs(OUTPUT_DIR, exist_ok=True)

df = pd.read_csv(INPUT_CSV)
print(f"Loaded {len(df)} rows from {INPUT_CSV}")

grouped = df.groupby("file")

for filename, group in grouped:
    chunk_data = []
    chunk_id = 0

    for _, row in group.iterrows():
        words = row["text"].split()
        total_chunks = math.ceil(len(words) / CHUNK_SIZE)

        for i in range(total_chunks):
            chunk_text = " ".join(words[i * CHUNK_SIZE : (i + 1) * CHUNK_SIZE])
            position = (
                round(chunk_id / (total_chunks - 1), 4) if total_chunks > 1 else 0.0
            )

            chunk_data.append(
                {
                    "file": row["file"],
                    "course": row["course"],
                    "source": row["source"],
                    "start": row["start"],
                    "end": row["end"],
                    "chunk_id": chunk_id,
                    "text": chunk_text,
                    "position": position,
                }
            )
            chunk_id += 1

    out_path = os.path.join(OUTPUT_DIR, filename.replace(".json", "_chunks.json"))
    with open(out_path, "w", encoding="utf-8") as f:
        json.dump(chunk_data, f, indent=2)

    print(f"Saved {len(chunk_data)} chunks to {out_path}")
# Out:
# Saved 31 chunks for s1
# Saved 25 chunks for s10
# Saved 26 chunks for s11
# Saved 26 chunks for s12
# Saved 25 chunks for s13
# Saved 27 chunks for s14
# Saved 27 chunks for s15
# Saved 26 chunks for s16
# Saved 27 chunks for s17
# Saved 30 chunks for s18
# Saved 25 chunks for s19
# Saved 36 chunks for s2
# Saved 24 chunks for s20
# Saved 25 chunks for s21
# Saved 24 chunks for s22
# Saved 23 chunks for s23
# Saved 23 chunks for s24
# Saved 24 chunks for s25
# Saved 25 chunks for s26
# Saved 26 chunks for s27
# Saved 24 chunks for s28
# Saved 26 chunks for s29
# Saved 34 chunks for s3
# Saved 26 chunks for s30
# Saved 25 chunks for s31
# Saved 26 chunks for s32
# Saved 30 chunks for s33
# Saved 27 chunks for s34
# Saved 30 chunks for s35
# Saved 29 chunks for s36
# Saved 32 chunks for s37
# Saved 25 chunks for s38
# Saved 26 chunks for s39
# Saved 32 chunks for s4
# Saved 26 chunks for s40
# Saved 27 chunks for s41
# Saved 26 chunks for s42
# Saved 24 chunks for s43
# Saved 26 chunks for s44
# Saved 26 chunks for s45
# Saved 26 chunks for s46
# Saved 26 chunks for s47
# Saved 30 chunks for s48
# Saved 27 chunks for s49
# Saved 33 chunks for s5
# Saved 25 chunks for s50
# Saved 31 chunks for s6
# Saved 28 chunks for s7
# Saved 27 chunks for s8
# Saved 26 chunks for s9
